# %% [markdown]
# # 中外合作办学项目 ---- 以辽宁分数线为准

# %% [markdown]
# Author: Heyuan LIU
#
# Contact: heyuan.liu@polytechnique.edu or heyuan.liu@epfl.ch
#
# ### welcome to contribute, feel free to create issues or pull requests!
# ### No commercial use allowed.
# ### Please add reference to the original source if you use any part of the code.

# %% [markdown]
# 注：
#
# 一些很强的高校并没有找到相关高考信息，不确定是否在辽宁招生
# 在此标注：
#
# 北航中法工程师学院，
#
# 浙大UIUC，
#
# 浙大爱丁堡，
#
# 上交密西根学院，
#
# 上交巴黎卓越工程师学院

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read xlsx
df = pd.read_excel('instructions.xlsx')

# %%
df
# Out:
#               院校  分数-2023                                                 专业  \
# 0         香港中文大学    662.0                                                 未知
# 1         香港城市大学    634.0                                                 未知
# 2     香港中文大学（深圳）    654.0                                                 未知
# 3           上海科技      NaN                                                 未知
# 4           昆山杜克      NaN                                                 未知
# 5           上海纽约      NaN                                                 未知
# 6           南方科技      NaN                                                 未知
# 7     香港科技大学（广州）      NaN                                                 未知
# 8   北京邮电大学(宏福校区)    625.0                                    电信工程及管理(中外合作办学)
# 9   北京邮电大学(宏福校区)    633.0                                      物联网工程(中外合作办学)
# 10  北京邮电大学(宏福校区)    635.0                                     电子信息工程(中外合作办学)
# ...

# %% [markdown]
# ## 按照2023年分数线排列的项目
# 自主招生控制线（一本线）
# 494

# %%
sorted_in_2023_score = df.sort_values(by='分数-2023', ascending=False)
sorted_in_2023_score
# Out:
#               院校  分数-2023                                                 专业  \
# 0         香港中文大学    662.0                                                 未知
# 17          同济大学    658.0  机械类(中外合作办学)[机械电子工程(中外合作办学)、建筑电气与智能化(中外合作办学)、汽车...
# 16  中国人民大学(苏州校区)    657.0                                    数学与应用数学(中外合作办学)
# 2     香港中文大学（深圳）    654.0                                                 未知
# 15  中国人民大学(苏州校区)    652.0                                        金融学(中外合作办学)
# 21          四川大学    645.0                                   计算机科学与技术(中外合作办学)
# 10  北京邮电大学(宏福校区)    635.0                                     电子信息工程(中外合作办学)
# 1         香港城市大学    634.0                                                 未知
# 9   北京邮电大学(宏福校区)    633.0                                      物联网工程(中外合作办学)
# 11  北京邮电大学(宏福校区)    632.0                                    智能科学与技术(中外合作办学)
# 22          四川大学    632.0                                     电子信息工程(中外合作办学)
# ...

# %% [markdown]
# ## 按照2022年分数线排列的项目

# %% [markdown]
# 自主招生控制线（一本线）
# 501

# %%
sorted_in_2022_score = df.sort_values(by='分数-2022', ascending=False)
sorted_in_2022_score
# Out:
#               院校  分数-2023                                                 专业  \
# 17          同济大学    658.0  机械类(中外合作办学)[机械电子工程(中外合作办学)、建筑电气与智能化(中外合作办学)、汽车...
# 3           上海科技      NaN                                                 未知
# 16  中国人民大学(苏州校区)    657.0                                    数学与应用数学(中外合作办学)
# 15  中国人民大学(苏州校区)    652.0                                        金融学(中外合作办学)
# 2     香港中文大学（深圳）    654.0                                                 未知
# 0         香港中文大学    662.0                                                 未知
# 21          四川大学    645.0                                   计算机科学与技术(中外合作办学)
# 9   北京邮电大学(宏福校区)    633.0                                      物联网工程(中外合作办学)
# 5           上海纽约      NaN                                                 未知
# 10  北京邮电大学(宏福校区)    635.0                                     电子信息工程(中外合作办学)
# 11  北京邮电大学(宏福校区)    632.0                                    智能科学与技术(中外合作办学)
# ...

# %% [markdown]
# # 按照合作院校的所在地区排列的项目

# %%
sorted_in_region_df = df.sort_values(by='合作院校地区', ascending=False)
sorted_in_region_df
# Out:
#               院校  分数-2023                                                 专业  \
# 8   北京邮电大学(宏福校区)    625.0                                    电信工程及管理(中外合作办学)
# 9   北京邮电大学(宏福校区)    633.0                                      物联网工程(中外合作办学)
# 27          暨南大学    594.0                                      经济统计学(中外合作办学)
# 26          暨南大学    604.0                                    信息与计算科学(中外合作办学)
# 25          暨南大学    598.0                                    数学与应用数学(中外合作办学)
# 24        西北工业大学    612.0                                   高分子材料与工程(中外合作办学)
# 23        西北工业大学    617.0                                    材料科学与工程(中外合作办学)
# 28          暨南大学    600.0                                        经济学(中外合作办学)
# 13  北京邮电大学(宏福校区)    598.0                                     数字媒体技术(中外合作办学)
# 12  北京邮电大学(宏福校区)    601.0                                    信息与计算科学(中外合作办学)
# 11  北京邮电大学(宏福校区)    632.0                                    智能科学与技术(中外合作办学)
# ...

# %% [markdown]
# ## 按照专业大类排列的项目

# %%
sorted_in_subject_df = df.sort_values(by='专业大类', ascending=False)
sorted_in_subject_df
# Out:
#               院校  分数-2023                                                 专业  \
# 35       西交利物浦大学    565.0             外国语言文学类(中外合作办学)[英语(中外合作办学)、翻译(中外合作办学)]
# 41       宁波诺丁汉大学    601.0                                   计算机科学与技术(中外合作办学)
# 40       宁波诺丁汉大学    624.0                              计算机科学与技术(中外合作办学)(2加2)
# 21          四川大学    645.0                                   计算机科学与技术(中外合作办学)
# 20          四川大学    621.0                                       工业工程(中外合作办学)
# 30       西交利物浦大学    569.0  电子信息类(中外合作办学)[计算机科学与技术(中外合作办学)、电子科学与技术(中外合作办学)...
# 8   北京邮电大学(宏福校区)    625.0                                    电信工程及管理(中外合作办学)
# 10  北京邮电大学(宏福校区)    635.0                                     电子信息工程(中外合作办学)
# 22          四川大学    632.0                                     电子信息工程(中外合作办学)
# 31       西交利物浦大学    567.0  生物科学类(中外合作办学)[生物科学(中外合作办学)、生物信息学(中外合作办学)、环境科学(...
# 23        西北工业大学    617.0                                    材料科学与工程(中外合作办学)
# ...

# %% [markdown]
# 备注：
#
# 1. 南方科技大学之前更换校长，最近两年人才略有流失。
#
# 2. 香港科技大学广州研究生体制被抱怨存在问题。
#
# 3. 未在表中列出的广东以色列理工学院每年在欧洲和美国申请结果还不错。
#
# 4. 谨慎选择国防相关院校，10043涉及学校，国防七子等会在申请美国或者加拿大受到阻碍，博士阶段会因为政治因素被拒绝，欧洲地区现在也会因为这个因素在博士申请阶段拒绝掉相关学历的人，例如，北京理工，北京航空航天，北京邮电，哈尔滨工业大学，哈尔滨工程大学等。
#
# 5. 澳门大学也可供选择，一般需要一本线上100+，申请制。
#
# 6. 港中文（深圳）港科技（广州）会因为法人问题无法享受海归政策，但目前在珠三角认可度还可以，港科技（广州）刚开没多久所以还没有具体参考
